# %% [markdown]
# Bronze layer: Raw Data Ingestion

# %%
df = spark.read.format("csv").option("header","true").option("sep", ";").option("inferSchema", "true").load("abfss://74113325-d1d1-4314-8ee1-24cf5d5d6ee6@onelake.dfs.fabric.microsoft.com/fdc8202c-3b99-4646-a005-3bc2e457b546/Files/WA_Fn-UseC_-Telco-Customer-Churn.csv")
# df now is a Spark DataFrame containing CSV data from "abfss://74113325-d1d1-4314-8ee1-24cf5d5d6ee6@onelake.dfs.fabric.microsoft.com/fdc8202c-3b99-4646-a005-3bc2e457b546/Files/WA_Fn-UseC_-Telco-Customer-Churn.csv".
display(df)
# Out:
# StatementMeta(, 45fbf51f-16b6-494c-8692-f4a6480f0ab7, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 73414f0e-7ba5-47ca-ba4e-474985017f76)

# %%
# save as bronze delta table
df.write.mode("overwrite").saveAsTable("bronze_customer_churn")
display(df)
# Out:
# StatementMeta(, 45fbf51f-16b6-494c-8692-f4a6480f0ab7, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7426b4b1-f63b-4bc3-b7a3-a7cc043f9334)

# %%
# %%sql
# -- validation, confirming if the bronze_customer_churn table loaded correctly
# -- preview first 10 rows
#
# SELECT * FROM bronze_customer_churn LIMIT 10;
# Out:
# StatementMeta(, d62a2c51-008f-4010-8f45-31f7e0064ec4, 2, Finished, Available, Finished, False)
# <Spark SQL result set with 10 rows and 21 fields>

# %%
# %%sql
# -- count total rows (expected: 7043)
#
# SELECT COUNT(*) AS total_rows FROM bronze_customer_churn;
# Out:
# StatementMeta(, bcfd6849-2cfa-4325-bfd3-ab8f487ffb54, 7, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 1 fields>

# %% [markdown]
# Silver layer: Cleaning data (Data Transformations)
